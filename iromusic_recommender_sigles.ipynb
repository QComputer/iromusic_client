# %% [markdown]
# # 🎬 iromusic Recommender System
#
# This notebook implements a music/movie recommender system using the data fetched from the iromusicapp.ir API.

# %% [markdown]
# ## 1. Data Loading

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import json
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8-whitegrid')

# %%
# Load music data
DATA_PATH_MUSIC_SINGLES = Path("iromusic_client//output//2026//02//27//music//singles")
json_files = list(DATA_PATH_MUSIC_SINGLES.glob("*.json"))
latest_file = max(json_files, key=lambda p: p.stat().st_mtime)
print(f"Loading: {latest_file.name}")

with open(latest_file, 'r', encoding='utf-8') as f:
    music_singles_data = json.load(f)

df_singles = pd.DataFrame(music_singles_data)
print(f"Dataset: {df_singles.shape[0]} music")
# Out:
# Loading: music_singles_2026-02-27_19-27-28.json
# Dataset: 67289 music

# %%
df_singles
# Out:
#            id     type                                    slug  \
# 0      290442  singles              ashvan-ft-mahyar-hamdast-2
# 1      290441  singles                 mojgan-shajarian-zahhak
# 2      290440  singles                       mansour-daya-daya
# 3      290439  singles       tiem-ft-sepehr-khalse-nemibinamet
# 4      290438  singles                    peyvand-ghobare-gham
# ...       ...      ...                                     ...
# 67284       7  singles                sina-hejazi-aghle-ahmagh
# 67285       6  singles                     gandom-mesle-ye-zan
# 67286       5  singles                 sogand-hichki-mesle-man
# 67287       4  singles  amir-exir-ft-armin-excel-donyaye-fargh
# 67288       3  singles         nazanin-abdollahi-be-yade-pedar
#
#            englishTitle alternateTitle  \
# 0               Hamdast        Hamdast
# 1                Zahhak           ضحاک
# 2             Daya Daya      Daya Daya
# 3           Nemibinamet      نمی‌بینمت
# ...
